# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
file = pd.read_csv('test_format.csv', sep=';')
file.replace('?', np.nan, inplace=True)
df_obj = file.select_dtypes(['object'])
file[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
file.head(10)
# Out:
# /Users/raptor/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (10,15,32,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 FAMILY                     FAMILY_DESC  \
# 0           1    NaN                             NaN
# 1           2    NaN                             NaN
# 2           3    NaN                             NaN
# 3           4    NaN                             NaN
# 4           5      0     **No Item Family Assigned**
# 5           6    NaN                             NaN
# 6           7      0     **No Item Family Assigned**
# 7           8      0     **No Item Family Assigned**
# 8           9   1607  INHALER, ASSIST DEVICES SPACER
# 9          10    NaN                             NaN
#
#                                    GLOBAL_ID_DESC GLOBAL_ID      NDC_NUM  \
# ...

# %%
file.columns.values
# Out:
# array(['Unnamed: 0', 'FAMILY', 'FAMILY_DESC', 'GLOBAL_ID_DESC',
#        'GLOBAL_ID', 'NDC_NUM', 'ITEM_NUMBER', 'ITEM_TYPE',
#        'PRIMARY_DESCRIPTION', 'GENERIC_NAME', 'SUPPLIER_ID',
#        'SUPPLIER_NAME', 'PRODUCT_KEY', 'GPI', 'GPI_NAME', 'GPI_RANK',
#        'DATETO', 'DATEFROM', 'ITEM_STATUS', 'MCK_SHORT_DATED_FLAG', 'RXDA',
#        'ONE_STOP', 'GENERIC', 'MS_GENERIC', 'GX_ALT_CODE',
#        'GX_UNIT_DOSE_IND', 'GX_OVERRIDE_PACK_SIZE', 'STATUS_FLAG',
#        'MS_PREFERRED', 'INJECTABLE', 'DESCRIPTION', 'GTIN', 'LIST_CD',
#        'PICK_DEPT', 'HOSPITAL_ITEM', 'DIVISION', 'MEMBERSHIP_CODE',
#        'MS_OLD_NDC', 'MS_MANUFACTURER_NAME', 'MS_PRODUCT_ABBR_NAME',
#        'MS_DOSAGE_FORM', 'MS_PACK_SIZE', 'MS_PACK_SZ_MULT',
#        'MS_TOTAL_PACK_SIZE', 'MS_PACK_SIZE_UOM', 'MS_METRIC_STRENGTH',
#        'MS_METRIC_STRENGTH_UOM', 'MS_PACKAGE_DESC', 'MS_UNIT_DOSE_IND',
#        'MS_TEE_CODE', 'FDB_MANUFACTURER_NAME', 'FDB_BRAND_NAME',
# ...

# %%
pandas_profiling.ProfileReport(file[['FAMILY','GLOBAL_ID','NDC_NUM','PRIMARY_DESCRIPTION', 'GENERIC_NAME', 'SUPPLIER_ID',
       'SUPPLIER_NAME','GPI','MCK_SHORT_DATED_FLAG', 'RXDA','ONE_STOP', 'GENERIC', 'MS_GENERIC','INJECTABLE','FDB_MANUFACTURER_NAME', 'FDB_BRAND_NAME',
       'FDB_DOSE_FORM', 'FDB_LABELER_NAME', 'FDB_DRUG_STRENGTH']])
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
