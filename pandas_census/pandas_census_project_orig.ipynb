# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("acs2015_census_tract_data.csv")
print(df.head())
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0    7.7     0.3      ...        0.5          2.3         2.1         25.0
# 1   53.3     0.0      ...        0.0          0.7         0.0         23.4
# 2   18.6     0.5      ...        0.0          0.0         2.5         19.6
# 3    3.7     1.6      ...        0.0          2.6         1.6         25.3
# 4   24.8     0.0      ...        0.0          0.6         0.9         24.8
#
# ...

# %%
df.describe()
# Out:
#         CensusTract      TotalPop           Men         Women      Hispanic  \
# count  7.400100e+04  74001.000000  74001.000000  74001.000000  73311.000000
# mean   2.839113e+10   4325.591465   2127.648816   2197.942649     16.862810
# std    1.647593e+10   2129.306903   1072.332031   1095.730931     22.940695
# min    1.001020e+09      0.000000      0.000000      0.000000      0.000000
# 25%    1.303901e+10   2891.000000   1409.000000   1461.000000      2.400000
# 50%    2.804700e+10   4063.000000   1986.000000   2066.000000      7.000000
# 75%    4.200341e+10   5442.000000   2674.000000   2774.000000     20.400000
# max    7.215375e+10  53812.000000  27962.000000  27250.000000    100.000000
#
#               White         Black        Native         Asian       Pacific  \
# count  73311.000000  73311.000000  73311.000000  73311.000000  73311.000000
# mean      62.032106     13.272581      0.727726      4.588253      0.145012
# ...

# %%
df.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
import numpy as np
#pd.pivot(df, values='column name', index ='column name', columns='column name', aggfunc=np.max)

#Which state has the most people working from home?
#df.groupby('State').sort_values('WorkAtHome', ascending=False)[10]

# %%
#Top 5 states with the most counties?
df.groupby('State').nunique().nlargest(5, 'County')
# Out:
#           CensusTract  State  County  TotalPop   Men  Women  Hispanic  White  \
# State
# Texas            5265      1     254      3850  2997   3004       960    949
# Georgia          1969      1     159      1733  1554   1571       338    818
# Virginia         1907      1     133      1634  1454   1419       316    782
# Kentucky         1115      1     120      1017   922    944       148    380
# Missouri         1393      1     115      1245  1138   1133       179    505
#
#           Black  Native      ...       Walk  OtherTransp  WorkAtHome  \
# State                        ...
# Texas       636      52      ...        185          144         187
# Georgia     759      39      ...        144          108         176
# Virginia    580      36      ...        171           96         160
# Kentucky    280      26      ...        134           91         118
# Missouri    384      43      ...        129           88         128
#
# ...

# %%
#Top 5 states with the largest income per capita
df.groupby('State').nunique().nlargest(5, 'IncomePerCap')
# Out:
#               CensusTract  State  County  TotalPop   Men  Women  Hispanic  \
# State
# California           8057      1      58      4680  3247   3261       986
# Texas                5265      1     254      3850  2997   3004       960
# New York             4918      1      62      3419  2525   2565       741
# Florida              4245      1      67      3220  2511   2582       761
# Pennsylvania         3218      1      67      2500  1987   2013       356
#
#               White  Black  Native      ...       Walk  OtherTransp  \
# State                                   ...
# California      941    461      99      ...        280          208
# Texas           949    636      52      ...        185          144
# New York        953    782      62      ...        401          151
# Florida         951    695      48      ...        175          171
# Pennsylvania    741    543      33      ...        283          122
#
# ...

# %%
#Top 5 states with the largest income per capita
df.groupby(['State', 'County']).nunique().nlargest(5, 'IncomePerCap')
# Out:
#                         CensusTract  State  County  TotalPop   Men  Women  \
# State      County
# California Los Angeles         2346      1       1      1895  1548   1590
# Illinois   Cook                1319      1       1      1206  1087   1086
# Arizona    Maricopa             916      1       1       843   782    799
# Texas      Harris               786      1       1       747   725    707
# New York   Kings                761      1       1       693   640    642
#
#                         Hispanic  White  Black  Native      ...       Walk  \
# State      County                                           ...
# California Los Angeles       872    740    385      37      ...        166
# Illinois   Cook              519    652    448      31      ...        188
# Arizona    Maricopa          501    568    171      92      ...         94
# Texas      Harris            514    480    374      27      ...         82
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Show total population by State
#df.groupby('State')['TotalPop'].sum().plot(kind='bar', x='State', y='TotalPop')
df.groupby('State').nunique().plot(kind='bar', y='State', x='TotalPop', figsize=(20, 5))
